# %% [markdown]
# ## 1. 데이터 로드하기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
path = '/content/drive/MyDrive/천안시청 교육과정/데이터/kidney_disease.csv'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1    notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2    notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3    notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4    notpresent  ...   35  7300  4.6   no   no   no  good   no   no
# ..          ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...
# 395  notpresent  ...   47  6700  4.9   no   no   no  good   no   no
# 396  notpresent  ...   54  7800  6.2   no   no   no  good   no   no
# 397  notpresent  ...   49  6600  5.4   no   no   no  good   no   no
# 398  notpresent  ...   51  7200  5.9   no   no   no  good   no   no
# 399  notpresent  ...   53  6800  6.1   no   no   no  good   no   no
#
#     classification
# 0              ckd
# 1              ckd
# 2              ckd
# 3              ckd
# 4              ckd
# ..             ...
# 395         notckd
# 396         notckd
# 397         notckd
# 398         notckd
# 399         notckd
#
# [400 rows x 26 columns]

# %% [markdown]
# ## 2. 데이터 살펴보기
# - 데이터의 일반정보
# - 데이터의 통계량
# - 데이터의 shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
#  17  wc              295 non-null    object
#  18  rc              270 non-null    object
#  19  htn             398 non-null    object
#  20  dm              398 non-null    object
#  21  cad             398 non-null    object
#  22  appet           399 non-null    object
#  23  pe              399 non-null    object
#  24  ane             399 non-null    object
#  25  classification  400 non-null    object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 81.4+ KB

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# std     79.281714   50.503006    5.741126   10.408752    3.193904    2.912587
# min     22.000000    1.500000    0.400000    4.500000    2.500000    3.100000
# 25%     99.000000   27.000000    0.900000  135.000000    3.800000   10.300000
# 50%    121.000000   42.000000    1.300000  138.000000    4.400000   12.650000
# 75%    163.000000   66.000000    2.800000  142.000000    4.900000   15.000000
# max    490.000000  391.000000   76.000000  163.000000   47.000000   17.800000

# %%
df.shape
# Out:
# (400, 26)

# %% [markdown]
# ## 3. 데이터의 전처리
#
# - 결측치가 전체의 30% 이상인 경우 해당 열을 제거하시오.
# - 결측치가 전체의 30% 미만인 경우, 평균값으로 대체하시오.

# %%
#행열 값을 저장해 놓고 활용하기 위함
row, col = df.shape

# %%
#어떤 열의 빈 값이 몇 개인지를 알아보는 함수
#해당 열의 공백 여부를 True, False로 인쇄함
#df['rbc'].isnull()

#해당 열의 공백이 총 몇개인지
df['rbc'].isnull().sum()
# Out:
# 152

# %%
empty = [x for x in df.columns if df[x].isnull().sum() >= int(row*0.3)]

# %%
empty
# Out:
# ['rbc', 'rc']

# %%
#columns = 열 이름으로 특정 열을 제거
df.drop(columns = empty, inplace=True)

# %%
#rbc와 rc 열이 사라짐
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'htn', 'dm', 'cad', 'appet',
#        'pe', 'ane', 'classification'],
#       dtype='object')

# %%
mean_ = [x for x in df.columns
         if df[x].isnull().sum() < row*0.3
         and df[x].isnull().sum() != 0]

# %%
mean_
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'pc',
#  'pcc',
#  'ba',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane']

# %%
#원래 평균값 대체였으나, object의 경우 평균을 낼 수 없으므로
#우선 최빈값 대체하였습니다.
for a in mean_:
  d_mode = df[a].mode()[0]
  df[a].fillna(d_mode, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             400 non-null    float64
#  2   bp              400 non-null    float64
#  3   sg              400 non-null    float64
#  4   al              400 non-null    float64
#  5   su              400 non-null    float64
#  6   pc              400 non-null    object
#  7   pcc             400 non-null    object
#  8   ba              400 non-null    object
#  9   bgr             400 non-null    float64
#  10  bu              400 non-null    float64
#  11  sc              400 non-null    float64
#  12  sod             400 non-null    float64
#  13  pot             400 non-null    float64
#  14  hemo            400 non-null    float64
#  15  pcv             400 non-null    object
#  16  wc              400 non-null    object
#  17  htn             400 non-null    object
#  18  dm              400 non-null    object
#  19  cad             400 non-null    object
#  20  appet           400 non-null    object
#  21  pe              400 non-null    object
#  22  ane             400 non-null    object
#  23  classification  400 non-null    object
# dtypes: float64(11), int64(1), object(12)
# memory usage: 75.1+ KB

# %% [markdown]
# ### 4. 데이터의 전처리 2
# - 데이터의 dtype이 'obejct' 인 경우,
#   - 알맞은 인코딩을 수행하시오.

# %%
ob = [x for x in df.columns if df[x].dtype=='object']

# %%
df[ob]
# Out:
#            pc         pcc          ba pcv    wc  htn   dm cad appet   pe  ane  \
# 0      normal  notpresent  notpresent  44  7800  yes  yes  no  good   no   no
# 1      normal  notpresent  notpresent  38  6000   no   no  no  good   no   no
# 2      normal  notpresent  notpresent  31  7500   no  yes  no  poor   no  yes
# 3    abnormal     present  notpresent  32  6700  yes   no  no  poor  yes  yes
# 4      normal  notpresent  notpresent  35  7300   no   no  no  good   no   no
# ..        ...         ...         ...  ..   ...  ...  ...  ..   ...  ...  ...
# 395    normal  notpresent  notpresent  47  6700   no   no  no  good   no   no
# 396    normal  notpresent  notpresent  54  7800   no   no  no  good   no   no
# 397    normal  notpresent  notpresent  49  6600   no   no  no  good   no   no
# 398    normal  notpresent  notpresent  51  7200   no   no  no  good   no   no
# 399    normal  notpresent  notpresent  53  6800   no   no  no  good   no   no
#
#     classification
# 0              ckd
# 1              ckd
# 2              ckd
# 3              ckd
# 4              ckd
# ..             ...
# 395         notckd
# 396         notckd
# 397         notckd
# 398         notckd
# 399         notckd
#
# [400 rows x 12 columns]

# %%
df['pcv'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', '41',
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '26', '15',
#        '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51', '54'],
#       dtype=object)

# %%
#pcv라는 열에 \t? 혹은 \t가 포함된 값이 존재하여 object로 인식
#해야 할 일 : \t가 들어간 값을 다른 숫자값으로 대체하고, 정수로 변환

# %%
df['pcv'].replace("\t43", 0, inplace=True)
df['pcv'].replace("\t?", 0, inplace=True)

# %%
df['pcv'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', '41',
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', 0, '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '26', '15',
#        '21', '43', '20', '47', '9', '49', '50', '53', '51', '54'],
#       dtype=object)

# %%
df['pcv'] = df['pcv'].astype(int)
mean = df['pcv'].mean()
df['pcv'].replace(0, mean, inplace=True)

# %%
df['pcv'].unique()
# Out:
# array([44.  , 38.  , 31.  , 32.  , 35.  , 39.  , 36.  , 33.  , 29.  ,
#        28.  , 41.  , 16.  , 24.  , 37.  , 30.  , 34.  , 40.  , 45.  ,
#        27.  , 48.  , 39.05, 52.  , 14.  , 22.  , 18.  , 42.  , 17.  ,
#        46.  , 23.  , 19.  , 25.  , 26.  , 15.  , 21.  , 43.  , 20.  ,
#        47.  ,  9.  , 49.  , 50.  , 53.  , 51.  , 54.  ])

# %%
df['wc'].unique()
# Out:
# array(['7800', '6000', '7500', '6700', '7300', '9800', '6900', '9600',
#        '12100', '4500', '12200', '11000', '3800', '11400', '5300', '9200',
#        '6200', '8300', '8400', '10300', '9100', '7900', '6400', '8600',
#        '18900', '21600', '4300', '8500', '11300', '7200', '7700', '14600',
#        '6300', '\t6200', '7100', '11800', '9400', '5500', '5800', '13200',
#        '12500', '5600', '7000', '11900', '10400', '10700', '12700',
#        '6800', '6500', '13600', '10200', '9000', '14900', '8200', '15200',
#        '5000', '16300', '12400', '\t8400', '10500', '4200', '4700',
#        '10900', '8100', '9500', '2200', '12800', '11200', '19100', '\t?',
#        '12300', '16700', '2600', '26400', '8800', '7400', '4900', '8000',
#        '12000', '15700', '4100', '5700', '11500', '5400', '10800', '9900',
#        '5200', '5900', '9300', '9700', '5100', '6600'], dtype=object)

# %%
df['wc'].replace('\t6200', 6200, inplace=True)
df['wc'].replace('\t?', 0, inplace=True)
df['wc'].replace('\t8400', 8400, inplace=True)

# %%
df['wc'] = df['wc'].astype(int)

#0을 빼고 평균 내는 방식
d_mean = df['wc'].mean()
df['wc'].replace(0, d_mean, inplace=True)

# %%
df['wc'].unique()
# Out:
# array([ 7800,  6000,  7500,  6700,  7300,  9800,  6900,  9600, 12100,
#         4500, 12200, 11000,  3800, 11400,  5300,  9200,  6200,  8300,
#         8400, 10300,  9100,  7900,  6400,  8600, 18900, 21600,  4300,
#         8500, 11300,  7200,  7700, 14600,  6300,  7100, 11800,  9400,
#         5500,  5800, 13200, 12500,  5600,  7000, 11900, 10400, 10700,
#        12700,  6800,  6500, 13600, 10200,  9000, 14900,  8200, 15200,
#         5000, 16300, 12400, 10500,  4200,  4700, 10900,  8100,  9500,
#         2200, 12800, 11200, 19100,  8751, 12300, 16700,  2600, 26400,
#         8800,  7400,  4900,  8000, 12000, 15700,  4100,  5700, 11500,
#         5400, 10800,  9900,  5200,  5900,  9300,  9700,  5100,  6600])

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su        pc         pcc          ba    bgr  \
# 0   0  48.0  80.0  1.020  1.0  0.0    normal  notpresent  notpresent  121.0
# 1   1   7.0  50.0  1.020  4.0  0.0    normal  notpresent  notpresent   99.0
# 2   2  62.0  80.0  1.010  2.0  3.0    normal  notpresent  notpresent  423.0
# 3   3  48.0  70.0  1.005  4.0  0.0  abnormal     present  notpresent  117.0
# 4   4  51.0  80.0  1.010  2.0  0.0    normal  notpresent  notpresent  106.0
#
#    ...  hemo   pcv    wc  htn   dm  cad  appet   pe  ane classification
# 0  ...  15.4  44.0  7800  yes  yes   no   good   no   no            ckd
# 1  ...  11.3  38.0  6000   no   no   no   good   no   no            ckd
# 2  ...   9.6  31.0  7500   no  yes   no   poor   no  yes            ckd
# 3  ...  11.2  32.0  6700  yes   no   no   poor  yes  yes            ckd
# 4  ...  11.6  35.0  7300   no   no   no   good   no   no            ckd
#
# [5 rows x 24 columns]

# %%
Y=df['classification']

# %%
ob
# Out:
# ['pc',
#  'pcc',
#  'ba',
#  'pcv',
#  'wc',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             400 non-null    float64
#  2   bp              400 non-null    float64
#  3   sg              400 non-null    float64
#  4   al              400 non-null    float64
#  5   su              400 non-null    float64
#  6   pc              400 non-null    object
#  7   pcc             400 non-null    object
#  8   ba              400 non-null    object
#  9   bgr             400 non-null    float64
#  10  bu              400 non-null    float64
#  11  sc              400 non-null    float64
#  12  sod             400 non-null    float64
#  13  pot             400 non-null    float64
#  14  hemo            400 non-null    float64
#  15  pcv             400 non-null    float64
#  16  wc              400 non-null    int64
#  17  htn             400 non-null    object
#  18  dm              400 non-null    object
#  19  cad             400 non-null    object
#  20  appet           400 non-null    object
#  21  pe              400 non-null    object
#  22  ane             400 non-null    object
#  23  classification  400 non-null    object
# dtypes: float64(12), int64(2), object(10)
# memory usage: 75.1+ KB

# %%
ob = [x for x in df.columns if df[x].dtype=='object']
ob = ob[:-1]

# %%
ob
# Out:
# ['pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane']

# %%
for o in ob:
  new_name = 'le'+o
  print(new_name)
# Out:
# lepc
# lepcc
# leba
# lehtn
# ledm
# lecad
# leappet
# lepe
# leane

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for o in ob:
  new_name = 'le'+o
  df[new_name] = le.fit_transform(df[o])
  df = pd.concat([df, df[new_name]], axis=1)

# %%
df
# Out:
#       id   age    bp     sg   al   su        pc         pcc          ba  \
# 0      0  48.0  80.0  1.020  1.0  0.0    normal  notpresent  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0    normal  notpresent  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0    normal  notpresent  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  abnormal     present  notpresent
# 4      4  51.0  80.0  1.010  2.0  0.0    normal  notpresent  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...         ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal  notpresent  notpresent
#
#        bgr  ...  ledm  ledm  lecad  lecad  leappet  leappet lepe lepe leane  \
# 0    121.0  ...     4     4      1      1        0        0    0    0     0
# 1     99.0  ...     3     3      1      1        0        0    0    0     0
# 2    423.0  ...     4     4      1      1        1        1    0    0     1
# 3    117.0  ...     3     3      1      1        1        1    1    1     1
# 4    106.0  ...     3     3      1      1        0        0    0    0     0
# ..     ...  ...   ...   ...    ...    ...      ...      ...  ...  ...   ...
# 395  140.0  ...     3     3      1      1        0        0    0    0     0
# 396   75.0  ...     3     3      1      1        0        0    0    0     0
# 397  100.0  ...     3     3      1      1        0        0    0    0     0
# 398  114.0  ...     3     3      1      1        0        0    0    0     0
# 399  131.0  ...     3     3      1      1        0        0    0    0     0
#
#     leane
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0
# ..    ...
# 395     0
# 396     0
# 397     0
# 398     0
# 399     0
#
# [400 rows x 42 columns]

# %%
df.drop(columns=ob, inplace=True)

# %%
df
# Out:
#       id   age    bp     sg   al   su    bgr    bu   sc    sod  ...  ledm  \
# 0      0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2  135.0  ...     4
# 1      1   7.0  50.0  1.020  4.0  0.0   99.0  18.0  0.8  135.0  ...     3
# 2      2  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8  135.0  ...     4
# 3      3  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  ...     3
# 4      4  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4  135.0  ...     3
# ..   ...   ...   ...    ...  ...  ...    ...   ...  ...    ...  ...   ...
# 395  395  55.0  80.0  1.020  0.0  0.0  140.0  49.0  0.5  150.0  ...     3
# 396  396  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  ...     3
# 397  397  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  ...     3
# 398  398  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  ...     3
# 399  399  58.0  80.0  1.025  0.0  0.0  131.0  18.0  1.1  141.0  ...     3
#
#      ledm  lecad  lecad  leappet  leappet  lepe  lepe  leane  leane
# 0       4      1      1        0        0     0     0      0      0
# 1       3      1      1        0        0     0     0      0      0
# 2       4      1      1        1        1     0     0      1      1
# 3       3      1      1        1        1     1     1      1      1
# 4       3      1      1        0        0     0     0      0      0
# ..    ...    ...    ...      ...      ...   ...   ...    ...    ...
# 395     3      1      1        0        0     0     0      0      0
# 396     3      1      1        0        0     0     0      0      0
# 397     3      1      1        0        0     0     0      0      0
# 398     3      1      1        0        0     0     0      0      0
# 399     3      1      1        0        0     0     0      0      0
#
# [400 rows x 33 columns]

# %% [markdown]
# ## 5. 데이터 준비하기
# - train, test데이터를 7:3의 비율로 나누어보시오

# %%
Y = le.fit_transform(Y)

# %%
from sklearn.model_selection import train_test_split

X=df
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %% [markdown]
# ## 6. 최소 2개 이상의 모델링을 하여, 각 모델의 성능을 비교하시오.

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train, Y_train)

predict = dt.predict(X_test)

from sklearn.metrics import accuracy_score

acc = accuracy_score(Y_test, predict)
print(acc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-8455c7ebf3d2> in <cell line: 4>()
#       2
#       3 dt = DecisionTreeClassifier()
# ----> 4 dt.fit(X_train, Y_train)
#       5
#       6 predict = dt.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     887         """
#     888
# --> 889         super().fit(
#     890             X,
#     891             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     184             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186             X, y = self._validate_data(
#     187                 X, y, validate_separately=(check_X_params, check_y_params)
#     188             )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     577                 if "estimator" not in check_X_params:
#     578                     check_X_params = {**default_check_params, **check_X_params}
# --> 579                 X = check_array(X, input_name="X", **check_X_params)
#     580                 if "estimator" not in check_y_params:
#     581                     check_y_params = {**default_check_params, **check_y_params}
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#
# ValueError: could not convert string to float: 'ckd'

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, Y_train)

predict = dt.predict(X_test)

from sklearn.metrics import accuracy_score

acc = accuracy_score(Y_test, predict)
print(acc)

# %% [markdown]
# ### 심화 : 파이썬에 너무 익숙한 사람
#
# - 시각화를 통해 데이터의 분포를 표현하시오(선택 1)
#
# - 두 모델의 성능 지표를 시각화하여 표현하시오(선택 2)

# %%
ob[0]
# Out:
# 'pc'

# %%
target_list = df['lepc']

# %%
target_list.head()
# Out:
#    lepc  lepc
# 0     1     1
# 1     1     1
# 2     1     1
# 3     0     0
# 4     1     1

# %%
target_list.columns = ['t1', 't2']

# %%
target_list
# Out:
#      t1  t2
# 0     1   1
# 1     1   1
# 2     1   1
# 3     0   0
# 4     1   1
# ..   ..  ..
# 395   1   1
# 396   1   1
# 397   1   1
# 398   1   1
# 399   1   1
#
# [400 rows x 2 columns]

# %%
#df의 ob[0] == 'pc' -> normal or abnormal
target_list = target_list['t1'].tolist()

# %%
#fig = 그림을 그리는 곳 , ax = 축
fig, ax = plt.subplots()
#ax.pie는 2가지요소 (1. 데이터를 리스트 형태로(갯수), 2.각 리스트의 요소 이름)
ax.pie([target_list.count(1),target_list.count(0)],
       labels=['normal', 'abnormal'])
# Out:
# ([<matplotlib.patches.Wedge at 0x78ecaa7b72b0>,
#   <matplotlib.patches.Wedge at 0x78ecaa3808b0>],
#  [Text(-0.9097886363331099, 0.6182917088228989, 'normal'),
#   Text(0.9097886363331099, -0.618291708822899, 'abnormal')])

# %%
fig, ax = plt.subplots()
ax.pie([1, 3, 4],
       labels=['a', 'ab', 'abc'])
# Out:
# ([<matplotlib.patches.Wedge at 0x78ecaa900070>,
#   <matplotlib.patches.Wedge at 0x78ecaa243be0>,
#   <matplotlib.patches.Wedge at 0x78ecaa7ce8c0>],
#  [Text(1.0162674857624154, 0.4209517756015988, 'a'),
#   Text(-0.42095177560159874, 1.0162674857624154, 'ab'),
#   Text(-2.0206672185931328e-16, -1.1, 'abc')])
